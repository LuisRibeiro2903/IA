# %%
# %run main.py
# Out:
# 1-Imprimir Grafo
# 2-Desenhar Grafo
# 3-Imprimir  nodos de Grafo
# 4-Imprimir arestas de Grafo
# 5-DFS
# 6-BFS
# 0-Saír
# 1-Imprimir Grafo
# 2-Desenhar Grafo
# 3-Imprimir  nodos de Grafo
# 4-Imprimir arestas de Grafo
# 5-DFS
# 6-BFS
# 0-Saír
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/Desktop/Aulas/3 ano/1 sem/IA/Aula4/main.py:87
#      83             l = input("prima enter para continuar")
#      86 if __name__ == "__main__":
# ---> 87     main()
#
# File ~/Desktop/Aulas/3 ano/1 sem/IA/Aula4/main.py:57, in main()
#      54 print("6-BFS")
#      55 print("0-Saír")
# ---> 57 saida = int(input("introduza a sua opcao-> "))
#      58 if saida == 0:
#      59     print("saindo.......")
#
# ValueError: invalid literal for int() with base 10: ''
